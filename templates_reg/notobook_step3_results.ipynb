# %%
import os
import pandas as pd
import pycaret.regression as reg

import utils as my

# %% [markdown]
# ## Monitoring & Check `history.csv`

# %% [markdown]
# ### Training results

# %%
df_history = pd.read_csv("./models/history.csv")
# df_history = df_history.loc[(df_history["R2"] > 0.8) & (df_history["RMSE"] < 4), :]
my.show_history(df_history, mode="Train", sort_by=['R2', 'RMSE'])
# Out:
# <style type="text/css">
# #T_4b462_row0_col0, #T_4b462_row0_col1, #T_4b462_row0_col2, #T_4b462_row0_col3, #T_4b462_row0_col4, #T_4b462_row0_col5, #T_4b462_row0_col6, #T_4b462_row0_col7, #T_4b462_row0_col8, #T_4b462_row7_col0, #T_4b462_row7_col1, #T_4b462_row7_col2, #T_4b462_row7_col3, #T_4b462_row7_col4, #T_4b462_row7_col5, #T_4b462_row7_col6, #T_4b462_row7_col7, #T_4b462_row7_col8, #T_4b462_row8_col0, #T_4b462_row8_col1, #T_4b462_row8_col2, #T_4b462_row8_col3, #T_4b462_row8_col4, #T_4b462_row8_col5, #T_4b462_row8_col6, #T_4b462_row8_col7, #T_4b462_row8_col8, #T_4b462_row12_col0, #T_4b462_row12_col1, #T_4b462_row12_col2, #T_4b462_row12_col3, #T_4b462_row12_col4, #T_4b462_row12_col5, #T_4b462_row12_col6, #T_4b462_row12_col7, #T_4b462_row12_col8, #T_4b462_row14_col0, #T_4b462_row14_col1, #T_4b462_row14_col2, #T_4b462_row14_col3, #T_4b462_row14_col4, #T_4b462_row14_col5, #T_4b462_row14_col6, #T_4b462_row14_col7, #T_4b462_row14_col8, #T_4b462_row24_col0, #T_4b462_row24_col1, #T_4b462_row24_col2, #T_4b462_row24_col3, #T_4b462_row24_col4, #T_4b462_row24_col5, #T_4b462_row24_col6, #T_4b462_row24_col7, #T_4b462_row24_col8, #T_4b462_row31_col0, #T_4b462_row31_col1, #T_4b462_row31_col2, #T_4b462_row31_col3, #T_4b462_row31_col4, #T_4b462_row31_col5, #T_4b462_row31_col6, #T_4b462_row31_col7, #T_4b462_row31_col8, #T_4b462_row32_col0, #T_4b462_row32_col1, #T_4b462_row32_col2, #T_4b462_row32_col3, #T_4b462_row32_col4, #T_4b462_row32_col5, #T_4b462_row32_col6, #T_4b462_row32_col7, #T_4b462_row32_col8, #T_4b462_row33_col0, #T_4b462_row33_col1, #T_4b462_row33_col2, #T_4b462_row33_col3, #T_4b462_row33_col4, #T_4b462_row33_col5, #T_4b462_row33_col6, #T_4b462_row33_col7, #T_4b462_row33_col8 {
#   color: blue;
# }
# #T_4b462_row1_col0, #T_4b462_row1_col1, #T_4b462_row1_col2, #T_4b462_row1_col3, #T_4b462_row1_col4, #T_4b462_row1_col5, #T_4b462_row1_col6, #T_4b462_row1_col7, #T_4b462_row1_col8, #T_4b462_row2_col0, #T_4b462_row2_col1, #T_4b462_row2_col2, #T_4b462_row2_col3, #T_4b462_row2_col4, #T_4b462_row2_col5, #T_4b462_row2_col6, #T_4b462_row2_col7, #T_4b462_row2_col8, #T_4b462_row3_col0, #T_4b462_row3_col1, #T_4b462_row3_col2, #T_4b462_row3_col3, #T_4b462_row3_col4, #T_4b462_row3_col5, #T_4b462_row3_col6, #T_4b462_row3_col7, #T_4b462_row3_col8, #T_4b462_row4_col0, #T_4b462_row4_col1, #T_4b462_row4_col2, #T_4b462_row4_col3, #T_4b462_row4_col4, #T_4b462_row4_col5, #T_4b462_row4_col6, #T_4b462_row4_col7, #T_4b462_row4_col8, #T_4b462_row5_col0, #T_4b462_row5_col1, #T_4b462_row5_col2, #T_4b462_row5_col3, #T_4b462_row5_col4, #T_4b462_row5_col5, #T_4b462_row5_col6, #T_4b462_row5_col7, #T_4b462_row5_col8, #T_4b462_row6_col0, #T_4b462_row6_col1, #T_4b462_row6_col2, #T_4b462_row6_col3, #T_4b462_row6_col4, #T_4b462_row6_col5, #T_4b462_row6_col6, #T_4b462_row6_col7, #T_4b462_row6_col8, #T_4b462_row10_col0, #T_4b462_row10_col1, #T_4b462_row10_col2, #T_4b462_row10_col3, #T_4b462_row10_col4, #T_4b462_row10_col5, #T_4b462_row10_col6, #T_4b462_row10_col7, #T_4b462_row10_col8, #T_4b462_row20_col0, #T_4b462_row20_col1, #T_4b462_row20_col2, #T_4b462_row20_col3, #T_4b462_row20_col4, #T_4b462_row20_col5, #T_4b462_row20_col6, #T_4b462_row20_col7, #T_4b462_row20_col8, #T_4b462_row22_col0, #T_4b462_row22_col1, #T_4b462_row22_col2, #T_4b462_row22_col3, #T_4b462_row22_col4, #T_4b462_row22_col5, #T_4b462_row22_col6, #T_4b462_row22_col7, #T_4b462_row22_col8, #T_4b462_row25_col0, #T_4b462_row25_col1, #T_4b462_row25_col2, #T_4b462_row25_col3, #T_4b462_row25_col4, #T_4b462_row25_col5, #T_4b462_row25_col6, #T_4b462_row25_col7, #T_4b462_row25_col8 {
#   color: black;
# }
# #T_4b462_row9_col0, #T_4b462_row9_col1, #T_4b462_row9_col2, #T_4b462_row9_col3, #T_4b462_row9_col4, #T_4b462_row9_col5, #T_4b462_row9_col6, #T_4b462_row9_col7, #T_4b462_row9_col8, #T_4b462_row13_col2, #T_4b462_row13_col3, #T_4b462_row13_col4, #T_4b462_row13_col7, #T_4b462_row13_col8, #T_4b462_row15_col0, #T_4b462_row15_col1, #T_4b462_row15_col2, #T_4b462_row15_col3, #T_4b462_row15_col4, #T_4b462_row15_col5, #T_4b462_row15_col6, #T_4b462_row15_col7, #T_4b462_row15_col8, #T_4b462_row16_col0, #T_4b462_row16_col1, #T_4b462_row16_col2, #T_4b462_row16_col3, #T_4b462_row16_col4, #T_4b462_row16_col5, #T_4b462_row16_col6, #T_4b462_row16_col7, #T_4b462_row16_col8, #T_4b462_row17_col0, #T_4b462_row17_col1, #T_4b462_row17_col2, #T_4b462_row17_col3, #T_4b462_row17_col4, #T_4b462_row17_col5, #T_4b462_row17_col6, #T_4b462_row17_col7, #T_4b462_row17_col8, #T_4b462_row18_col0, #T_4b462_row18_col1, #T_4b462_row18_col2, #T_4b462_row18_col3, #T_4b462_row18_col4, #T_4b462_row18_col5, #T_4b462_row18_col6, #T_4b462_row18_col7, #T_4b462_row18_col8, #T_4b462_row19_col0, #T_4b462_row19_col1, #T_4b462_row19_col2, #T_4b462_row19_col3, #T_4b462_row19_col4, #T_4b462_row19_col5, #T_4b462_row19_col6, #T_4b462_row19_col7, #T_4b462_row19_col8, #T_4b462_row21_col1, #T_4b462_row21_col3, #T_4b462_row21_col4, #T_4b462_row21_col5, #T_4b462_row21_col8, #T_4b462_row23_col0, #T_4b462_row23_col1, #T_4b462_row23_col2, #T_4b462_row23_col3, #T_4b462_row23_col4, #T_4b462_row26_col0, #T_4b462_row26_col1, #T_4b462_row26_col2, #T_4b462_row26_col3, #T_4b462_row26_col4, #T_4b462_row26_col5, #T_4b462_row26_col6, #T_4b462_row26_col7, #T_4b462_row26_col8, #T_4b462_row27_col0, #T_4b462_row27_col1, #T_4b462_row27_col2, #T_4b462_row27_col3, #T_4b462_row27_col4, #T_4b462_row27_col5, #T_4b462_row27_col6, #T_4b462_row27_col7, #T_4b462_row27_col8, #T_4b462_row28_col0, #T_4b462_row28_col1, #T_4b462_row28_col2, #T_4b462_row28_col3, #T_4b462_row28_col4, #T_4b462_row28_col5, #T_4b462_row28_col6, #T_4b462_row28_col7, #T_4b462_row28_col8, #T_4b462_row29_col0, #T_4b462_row29_col1, #T_4b462_row29_col2, #T_4b462_row29_col3, #T_4b462_row29_col4, #T_4b462_row29_col5, #T_4b462_row29_col6, #T_4b462_row29_col7, #T_4b462_row29_col8, #T_4b462_row30_col0, #T_4b462_row30_col1, #T_4b462_row30_col2, #T_4b462_row30_col3, #T_4b462_row30_col4, #T_4b462_row30_col5, #T_4b462_row30_col6, #T_4b462_row30_col7, #T_4b462_row30_col8 {
#   color: gray;
# }
# #T_4b462_row11_col0, #T_4b462_row11_col1, #T_4b462_row11_col2, #T_4b462_row11_col3, #T_4b462_row11_col4, #T_4b462_row11_col5, #T_4b462_row11_col6, #T_4b462_row11_col7, #T_4b462_row11_col8, #T_4b462_row13_col0, #T_4b462_row13_col1, #T_4b462_row13_col5, #T_4b462_row13_col6, #T_4b462_row21_col0, #T_4b462_row21_col2, #T_4b462_row21_col6, #T_4b462_row21_col7, #T_4b462_row23_col5, #T_4b462_row23_col6, #T_4b462_row23_col7, #T_4b462_row23_col8 {
#   color: red;
# }
# </style>
# <table id="T_4b462">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b462_level0_col0" class="col_heading level0 col0" >15</th>
#       <th id="T_4b462_level0_col1" class="col_heading level0 col1" >11</th>
#       <th id="T_4b462_level0_col2" class="col_heading level0 col2" >7</th>
#       <th id="T_4b462_level0_col3" class="col_heading level0 col3" >1</th>
#       <th id="T_4b462_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_4b462_level0_col5" class="col_heading level0 col5" >13</th>
#       <th id="T_4b462_level0_col6" class="col_heading level0 col6" >17</th>
#       <th id="T_4b462_level0_col7" class="col_heading level0 col7" >9</th>
#       <th id="T_4b462_level0_col8" class="col_heading level0 col8" >5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b462_level0_row0" class="row_heading level0 row0" >Model</th>
#       <td id="T_4b462_row0_col0" class="data row0 col0" >base</td>
#       <td id="T_4b462_row0_col1" class="data row0 col1" >base</td>
#       <td id="T_4b462_row0_col2" class="data row0 col2" >base</td>
#       <td id="T_4b462_row0_col3" class="data row0 col3" >base</td>
#       <td id="T_4b462_row0_col4" class="data row0 col4" >base</td>
#       <td id="T_4b462_row0_col5" class="data row0 col5" >base</td>
#       <td id="T_4b462_row0_col6" class="data row0 col6" >base</td>
#       <td id="T_4b462_row0_col7" class="data row0 col7" >base</td>
#       <td id="T_4b462_row0_col8" class="data row0 col8" >base</td>
#     </tr>
#     <tr>
#       <th id="T_4b462_level0_row1" class="row_heading l

# %% [markdown]
# ### Test restuls

# %%
df_history = pd.read_csv("./models/history.csv")
df_history = df_history.loc[(df_history["R2"] > 0.8) & (df_history["RMSE"] < 4), :]
my.show_history(df_history, mode="Test", sort_by=['R2', 'RMSE'])
# Out:
# <style type="text/css">
# #T_8ec31_row0_col0, #T_8ec31_row0_col1, #T_8ec31_row0_col2, #T_8ec31_row0_col3, #T_8ec31_row0_col4, #T_8ec31_row0_col5, #T_8ec31_row0_col6, #T_8ec31_row7_col0, #T_8ec31_row7_col1, #T_8ec31_row7_col2, #T_8ec31_row7_col3, #T_8ec31_row7_col4, #T_8ec31_row7_col5, #T_8ec31_row7_col6, #T_8ec31_row8_col0, #T_8ec31_row8_col1, #T_8ec31_row8_col2, #T_8ec31_row8_col3, #T_8ec31_row8_col4, #T_8ec31_row8_col5, #T_8ec31_row8_col6, #T_8ec31_row12_col0, #T_8ec31_row12_col1, #T_8ec31_row12_col2, #T_8ec31_row12_col3, #T_8ec31_row12_col4, #T_8ec31_row12_col5, #T_8ec31_row12_col6, #T_8ec31_row14_col0, #T_8ec31_row14_col1, #T_8ec31_row14_col2, #T_8ec31_row14_col3, #T_8ec31_row14_col4, #T_8ec31_row14_col5, #T_8ec31_row14_col6, #T_8ec31_row24_col0, #T_8ec31_row24_col1, #T_8ec31_row24_col2, #T_8ec31_row24_col3, #T_8ec31_row24_col4, #T_8ec31_row24_col5, #T_8ec31_row24_col6, #T_8ec31_row31_col0, #T_8ec31_row31_col1, #T_8ec31_row31_col2, #T_8ec31_row31_col3, #T_8ec31_row31_col4, #T_8ec31_row31_col5, #T_8ec31_row31_col6, #T_8ec31_row32_col0, #T_8ec31_row32_col1, #T_8ec31_row32_col2, #T_8ec31_row32_col3, #T_8ec31_row32_col4, #T_8ec31_row32_col5, #T_8ec31_row32_col6, #T_8ec31_row33_col0, #T_8ec31_row33_col1, #T_8ec31_row33_col2, #T_8ec31_row33_col3, #T_8ec31_row33_col4, #T_8ec31_row33_col5, #T_8ec31_row33_col6 {
#   color: blue;
# }
# #T_8ec31_row1_col0, #T_8ec31_row1_col1, #T_8ec31_row1_col2, #T_8ec31_row1_col3, #T_8ec31_row1_col4, #T_8ec31_row1_col5, #T_8ec31_row1_col6, #T_8ec31_row2_col0, #T_8ec31_row2_col1, #T_8ec31_row2_col2, #T_8ec31_row2_col3, #T_8ec31_row2_col4, #T_8ec31_row2_col5, #T_8ec31_row2_col6, #T_8ec31_row3_col0, #T_8ec31_row3_col1, #T_8ec31_row3_col2, #T_8ec31_row3_col3, #T_8ec31_row3_col4, #T_8ec31_row3_col5, #T_8ec31_row3_col6, #T_8ec31_row4_col0, #T_8ec31_row4_col1, #T_8ec31_row4_col2, #T_8ec31_row4_col3, #T_8ec31_row4_col4, #T_8ec31_row4_col5, #T_8ec31_row4_col6, #T_8ec31_row5_col0, #T_8ec31_row5_col1, #T_8ec31_row5_col2, #T_8ec31_row5_col3, #T_8ec31_row5_col4, #T_8ec31_row5_col5, #T_8ec31_row5_col6, #T_8ec31_row6_col0, #T_8ec31_row6_col1, #T_8ec31_row6_col2, #T_8ec31_row6_col3, #T_8ec31_row6_col4, #T_8ec31_row6_col5, #T_8ec31_row6_col6, #T_8ec31_row10_col0, #T_8ec31_row10_col1, #T_8ec31_row10_col2, #T_8ec31_row10_col3, #T_8ec31_row10_col4, #T_8ec31_row10_col5, #T_8ec31_row10_col6, #T_8ec31_row20_col0, #T_8ec31_row20_col1, #T_8ec31_row20_col2, #T_8ec31_row20_col3, #T_8ec31_row20_col4, #T_8ec31_row20_col5, #T_8ec31_row20_col6, #T_8ec31_row22_col0, #T_8ec31_row22_col1, #T_8ec31_row22_col2, #T_8ec31_row22_col3, #T_8ec31_row22_col4, #T_8ec31_row22_col5, #T_8ec31_row22_col6, #T_8ec31_row25_col0, #T_8ec31_row25_col1, #T_8ec31_row25_col2, #T_8ec31_row25_col3, #T_8ec31_row25_col4, #T_8ec31_row25_col5, #T_8ec31_row25_col6 {
#   color: black;
# }
# #T_8ec31_row9_col0, #T_8ec31_row9_col1, #T_8ec31_row9_col2, #T_8ec31_row9_col3, #T_8ec31_row9_col4, #T_8ec31_row9_col5, #T_8ec31_row9_col6, #T_8ec31_row13_col3, #T_8ec31_row13_col5, #T_8ec31_row13_col6, #T_8ec31_row15_col0, #T_8ec31_row15_col1, #T_8ec31_row15_col2, #T_8ec31_row15_col3, #T_8ec31_row15_col4, #T_8ec31_row15_col5, #T_8ec31_row15_col6, #T_8ec31_row16_col0, #T_8ec31_row16_col1, #T_8ec31_row16_col2, #T_8ec31_row16_col3, #T_8ec31_row16_col4, #T_8ec31_row16_col5, #T_8ec31_row16_col6, #T_8ec31_row17_col0, #T_8ec31_row17_col1, #T_8ec31_row17_col2, #T_8ec31_row17_col3, #T_8ec31_row17_col4, #T_8ec31_row17_col5, #T_8ec31_row17_col6, #T_8ec31_row18_col0, #T_8ec31_row18_col1, #T_8ec31_row18_col2, #T_8ec31_row18_col3, #T_8ec31_row18_col4, #T_8ec31_row18_col5, #T_8ec31_row18_col6, #T_8ec31_row19_col0, #T_8ec31_row19_col1, #T_8ec31_row19_col2, #T_8ec31_row19_col3, #T_8ec31_row19_col4, #T_8ec31_row19_col5, #T_8ec31_row19_col6, #T_8ec31_row21_col1, #T_8ec31_row21_col2, #T_8ec31_row21_col5, #T_8ec31_row21_col6, #T_8ec31_row23_col0, #T_8ec31_row23_col1, #T_8ec31_row23_col3, #T_8ec31_row23_col5, #T_8ec31_row23_col6, #T_8ec31_row26_col0, #T_8ec31_row26_col1, #T_8ec31_row26_col2, #T_8ec31_row26_col3, #T_8ec31_row26_col4, #T_8ec31_row26_col5, #T_8ec31_row26_col6, #T_8ec31_row27_col0, #T_8ec31_row27_col1, #T_8ec31_row27_col2, #T_8ec31_row27_col3, #T_8ec31_row27_col4, #T_8ec31_row27_col5, #T_8ec31_row27_col6, #T_8ec31_row28_col0, #T_8ec31_row28_col1, #T_8ec31_row28_col2, #T_8ec31_row28_col3, #T_8ec31_row28_col4, #T_8ec31_row28_col5, #T_8ec31_row28_col6, #T_8ec31_row29_col0, #T_8ec31_row29_col1, #T_8ec31_row29_col2, #T_8ec31_row29_col3, #T_8ec31_row29_col4, #T_8ec31_row29_col5, #T_8ec31_row29_col6, #T_8ec31_row30_col0, #T_8ec31_row30_col1, #T_8ec31_row30_col2, #T_8ec31_row30_col3, #T_8ec31_row30_col4, #T_8ec31_row30_col5, #T_8ec31_row30_col6 {
#   color: gray;
# }
# #T_8ec31_row11_col0, #T_8ec31_row11_col1, #T_8ec31_row11_col2, #T_8ec31_row11_col3, #T_8ec31_row11_col4, #T_8ec31_row11_col5, #T_8ec31_row11_col6, #T_8ec31_row13_col0, #T_8ec31_row13_col1, #T_8ec31_row13_col2, #T_8ec31_row13_col4, #T_8ec31_row21_col0, #T_8ec31_row21_col3, #T_8ec31_row21_col4, #T_8ec31_row23_col2, #T_8ec31_row23_col4 {
#   color: red;
# }
# </style>
# <table id="T_8ec31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ec31_level0_col0" class="col_heading level0 col0" >15</th>
#       <th id="T_8ec31_level0_col1" class="col_heading level0 col1" >11</th>
#       <th id="T_8ec31_level0_col2" class="col_heading level0 col2" >13</th>
#       <th id="T_8ec31_level0_col3" class="col_heading level0 col3" >7</th>
#       <th id="T_8ec31_level0_col4" class="col_heading level0 col4" >17</th>
#       <th id="T_8ec31_level0_col5" class="col_heading level0 col5" >1</th>
#       <th id="T_8ec31_level0_col6" class="col_heading level0 col6" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ec31_level0_row0" class="row_heading level0 row0" >Model</th>
#       <td id="T_8ec31_row0_col0" class="data row0 col0" >base</td>
#       <td id="T_8ec31_row0_col1" class="data row0 col1" >base</td>
#       <td id="T_8ec31_row0_col2" class="data row0 col2" >base</td>
#       <td id="T_8ec31_row0_col3" class="data row0 col3" >base</td>
#       <td id="T_8ec31_row0_col4" class="data row0 col4" >base</td>
#       <td id="T_8ec31_row0_col5" class="data row0 col5" >base</td>
#       <td id="T_8ec31_row0_col6" class="data row0 col6" >base</td>
#     </tr>
#     <tr>
#       <th id="T_8ec31_level0_row1" class="row_heading level0 row1" >MAE</th>
#       <td id="T_8ec31_row1_col0" class="data row1 col0" >2.134200</td>
#       <td id="T_8ec31_row1_col1" class="data row1 col1" >2.146300</td>
#       <td id="T_8ec31_row1_col2" class="data row1 col2" >2.094900</td>
#       <td id="T_8ec31_row1_col3" class="data row1 col3" >2.294000</td>
#       <td id="T_8ec31_row1_col4" class="data row1 col4" >2.415400</td>
#       <td id="T_8ec31_row1_col5" class="data row1 col5" >2.429600</td>
#       <td id="T_8ec31_row1_col6" class="data row1 col6" >2.429600</td>
#     </tr>
#     <tr>
#       <th id="T_8ec31_level0_row2" class="row_heading level0 row2" >MSE</th>
#       <td id="T_8ec31_row2_col0" class="data row2 col0" >10.910600</td>
#       <td id="T_8ec31_row2_col1" class="data row2 col1" >10.941700</td>
#       <td id="T_8ec31_row2_col2" class="data row2 col2" >11.755700</td>
#       <td id="T_8ec31_row2_col3" class="data row2 col3" >13.243900</td>
#       <td id="T_8ec31_row2_col4" class="data row2 col4" >14.748100</td>
#       <td id="T_8ec31_row2_col5" class="data row2 col5" >14.854000</td>
#       <td id="T_8ec31_row2_col6" class="data row2 col6" >14.854000</td>
#     </tr>
#     <tr>
#       <th id="T_8ec31_level0_row3" class="row_heading level0 row3" >RMSE</th>
#       <td id="T_8ec31_row3_col0" class="data row3 col0" >3.303100</td>
#       <td id="T_8ec31_row3_col1" class="data row3 col1" >3.307800</td>
#       <td id="T_8ec31_row3_col2" class="data row3 col2" >3.428700</td>
#       <td id="T_8ec31_row3_col3" class="data row3 col3" >3.639200</td>
#       <td id="T_8ec31_row3_col4" class="data row3 col4" >3.840300</td>
#       <td id="T_8ec31_row3_col5" class="data row3 col5" >3.854100</td>
#       <td id="T_8ec31_row3_col6" class="data row3

# %% [markdown]
# ## Metrics

# %%
dataset = pd.read_csv("./boston-housing.csv",
                      header=None, delimiter=r"\s+",
                      names=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE',
                             'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'])
target_name = "MEDV"
train_size = 0.75
seed = 111

train, test = my.get_data(dataset, train_size, seed)
# Out:
# Train Data: (380, 14)
# Test  Data: (126, 14)

# %% [markdown]
# ### Default model (all default parameters)

# %%
## Default model
model_name = "base__train__R2-0.9810_RMSE-1.2797__test__R2-0.8130_RMSE-3.8541__seed-111"
model = reg.load_model(os.path.join("./models", model_name))
train_scores = my.get_scores(model, train, train[target_name])
test_scores = my.get_scores(model, test, test[target_name])

print(">>", type(model.steps[-1][-1]))
# print(">>", [x[0] for x in model.steps[-1][-1].estimators])
# print(">>", model.steps[-1][-1])
print(">> Train scores:\n", train_scores)
print(">> Test scores:\n", test_scores)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# >> <class 'sklearn.ensemble._stacking.StackingRegressor'>
# >> Train scores:
#    Model     MAE     MSE    RMSE     R2   RMSLE    MAPE Tact
# 0        0.9966  1.6376  1.2797  0.981  0.1213  0.0554
# >> Test scores:
#    Model     MAE     MSE    RMSE     R2   RMSLE    MAPE Tact
# 0        2.4296  14.854  3.8541  0.813  0.2519  0.1234

# %% [markdown]
# ### Baseline model

# %%
model_name = "base__train__R2-0.9822_RMSE-1.2389__test__R2-0.8332_RMSE-3.6392__seed-111"
model = reg.load_model(os.path.join("./models", model_name))
train_scores = my.get_scores(model, train, train[target_name])
test_scores = my.get_scores(model, test, test[target_name])

print(">>", type(model.steps[-1][-1]))
# print(">>", [x[0] for x in model.steps[-1][-1].estimators])
# print(">>", model.steps[-1][-1])
print(">> Train scores:\n", train_scores)
print(">> Test scores:\n", test_scores)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# >> <class 'sklearn.ensemble._stacking.StackingRegressor'>
# >> Train scores:
#    Model     MAE     MSE    RMSE      R2   RMSLE   MAPE Tact
# 0        0.9566  1.5349  1.2389  0.9822  0.1155  0.052
# >> Test scores:
#    Model    MAE      MSE    RMSE      R2   RMSLE    MAPE Tact
# 0        2.294  13.2439  3.6392  0.8332  0.2385  0.1163

# %% [markdown]
# ### Tuned models

# %%
model_name = "base__train__R2-0.9964_RMSE-0.5582__test__R2-0.8626_RMSE-3.3031__seed-111"
model = reg.load_model(os.path.join("./models", model_name))
train_scores = my.get_scores(model, train, train[target_name])
test_scores = my.get_scores(model, test, test[target_name])

print(">>", type(model.steps[-1][-1]))
# print(">>", [x[0] for x in model.steps[-1][-1].estimators])
# print(">>", model.steps[-1][-1])
print(">> Train scores:\n", train_scores)
print(">> Test scores:\n", test_scores)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# >> <class 'sklearn.ensemble._voting.VotingRegressor'>
# >> Train scores:
#    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE Tact
# 0        0.3955  0.3116  0.5582  0.9964  0.0298  0.0212
# >> Test scores:
#    Model     MAE      MSE    RMSE      R2   RMSLE    MAPE Tact
# 0        2.1342  10.9106  3.3031  0.8626  0.1347  0.1039
